# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
business_path='C:\yelp_dataset\yelp_academic_dataset_business.json'
df_business=pd.read_json(business_path, lines=True)

# %%
display(df_business)
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1       87 Grasso Plaza Shopping Center         Affton    MO       63123
# ...

# %%
checkin_path='C:\yelp_dataset\yelp_academic_dataset_checkin.json'
df_checkin=pd.read_json(checkin_path, lines=True)

# %%
display(df_checkin)
# Out:
#                    business_id  \
# 0       ---kPU91CF4Lq2-WlRu9Lw
# 1       --0iUa4sNDFiZFrAdIWhZQ
# 2       --30_8IhuyMHbSOcNWd6DQ
# 3       --7PUidqRWpRSpXebiyxTg
# 4       --7jw19RH9JKXgFohspgQw
# ...                        ...
# 131925  zznJox6-nmXlGYNWgTDwQQ
# 131926  zznZqH9CiAznbkV6fXyHWA
# 131927  zzu6_r3DxBJuXcjnOYVdTw
# 131928  zzw66H6hVjXQEt0Js3Mo4A
# 131929  zzyx5x0Z7xXWWvWnZFuxlQ
#
#                                                      date
# 0       2020-03-13 21:10:56, 2020-06-02 22:18:06, 2020...
# 1       2010-09-13 21:43:09, 2011-05-04 23:08:15, 2011...
# 2                2013-06-14 23:29:17, 2014-08-13 23:20:22
# 3       2011-02-15 17:12:00, 2011-07-28 02:46:10, 2012...
# 4       2014-04-21 20:42:11, 2014-04-28 21:04:46, 2014...
# ...                                                   ...
# 131925  2013-03-23 16:22:47, 2013-04-07 02:03:12, 2013...
# 131926                                2021-06-12 01:16:12
# ...

# %%
def read_chunks(file, cols, chunk_size=500000):
    df = pd.read_json(
        f'C:\yelp_dataset\yelp_academic_dataset_{file}.json', chunksize = chunk_size, lines=True)
    
    chunk_list = [chunk[cols] for chunk in df ]

    return pd.concat(chunk_list, ignore_index = True, join = 'outer', axis = 0)

# %%
df_user = read_chunks('user', ['user_id','name','friends','fans'])

# %%
df_user
# Out:
#                         user_id     name  \
# 0        qVc8ODYU5SZjKXVBgXdI7w   Walker
# 1        j14WgRoU_-2ZE1aw1dXrJg   Daniel
# 2        2WnXYQFK0hXEoTxPtV2zvg    Steph
# 3        SZDeASXq7o05mMNLshsdIA     Gwen
# 4        hA5lMy-EnncsH4JoR-hFGQ    Karen
# ...                         ...      ...
# 1987892  fB3jbHi3m0L2KgGOxBv6uw  Jerrold
# 1987893  68czcr4BxJyMQ9cJBm6C7Q     Jane
# 1987894  1x3KMskYxOuJCjRz70xOqQ  Shomari
# 1987895  ulfGl4tdbrH05xKzh5lnog  Susanne
# 1987896  wL5jPrLRVCK_Pmo4lM1zpA      Isa
#
#                                                    friends  fans
# 0        NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267
# 1        ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...  3138
# 2        LuO3Bn4f3rlhyHIaNfTlnA, j9B4XdHUhDfTKVecyWQgyA...    52
# 3        enx1vVPnfdNUdPho6PH_wg, 4wOcvMLtU6a9Lslggq74Vg...    28
# 4        PBK4q9KEEBHhFvSXCUirIw, 3FWPpM7KU1gXeOM_ZbYMbA...     1
# ...                                                    ...   ...
# ...

# %%
df_business_PHIL = df_business[df_business['city'].str.lower().isin(['philadelphia'])]

# %%
df_business_PHIL
# Out:
#                    business_id                                 name  \
# 3       MTSW4McQd7CbVtyjqoe9mw                   St Honore Pastries
# 15      MUTTqe8uqyMdBl186RmNeA                             Tuna Bar
# 19      ROeacJQwBeh05Rqg7F6TCg                                  BAP
# 28      QdN72BWoyFypdGJhhI5r7g                              Bar One
# 31      Mjboz24M9NlBeiOJKLEd_Q                     DeSandro on Main
# ...                        ...                                  ...
# 150320  wPAaAbFbq5wfLfW0gnYU7g                             Intermix
# 150326  JDM7kiCEmeBc_5W-z6eZZw              2601 Parkway Apartments
# 150329  9U1Igcpe954LoWZRmNc-zg  Hand & Stone Massage And Facial Spa
# 150334  LJ4GjQ1HL6kqvIPpNUNNaQ             Shanti Yoga and Ayurveda
# 150336  WnT9NIzQgLlILjPT0kEcsQ        Adelita Taqueria & Restaurant
#
#                              address          city state postal_code  \
# 3                        935 Race St  Philadelphia    PA       19107
# ...

# %%
df_review = read_chunks('review', ['review_id','user_id','business_id','stars'])

# %%
df_review
# Out:
#                       review_id                 user_id  \
# 0        KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1        BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 2        saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3        AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 4        Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
# ...                         ...                     ...
# 6990275  H0RIamZu0B0Ei0P4aeh3sQ  qskILQ3k0I_qcCMI-k6_QQ
# 6990276  shTPgbgdwTHSuU67mGCmZQ  Zo0th2m8Ez4gLSbHftiQvg
# 6990277  YNfNhgZlaaCO5Q_YJR4rEw  mm6E4FbCMwJmb7kPDZ5v2Q
# 6990278  i-I4ZOhoX70Nw5H0FwrQUA  YwAMC-jvZ1fvEUum6QkEkw
# 6990279  RwcKOdEuLRHNJe4M9-qpqg  6JehEvdoCvZPJ_XIxnzIIw
#
#                     business_id  stars
# 0        XQfwVwDr-v0ZS3_CbbE5Xw      3
# 1        7ATYjTIgM3jUlt4UM3IypQ      5
# 2        YjUWPpI6HXG530lwP-fb2A      3
# 3        kxX2SOes4o-D3ZQBkiMRfA      5
# 4        e4Vwtrqf-wpJfwesgvdgxQ      4
# ...                         ...    ...
# ...

# %%
df_review_PHIL=df_review[df_review['business_id'].isin(df_business_PHIL['business_id'])]

# %%
df_review_PHIL
# Out:
#                       review_id                 user_id  \
# 1        BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 3        AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 5        JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A
# 13       8JFGBuHMoiNDyfcxuWNtrA  smOvOajNG0lS4Pq7d8g4JQ
# 16       oyaMhzBSwfGgemSGuZCdwQ  Dd1jQj7S-BFGqRbApFzCFw
# ...                         ...                     ...
# 6990257  tWCi4N2qCil876BI2NDAZg  5d32aJe0a3_fSl3LIVYkWQ
# 6990260  nLjbVsETpqO17RbFcqskkA  am7-gkH_PDz598oTdYSD6A
# 6990263  99ylx-qPUSseITqBye2MpA  -AkziDwQ8hv2COTDBBUpig
# 6990265  KlHxcAifUF5zDKpJCBrRsw  7ziWZULyiZv2TesYNMFf4g
# 6990269  cACxcUY_AIsQKkpDRXuqnw  MCzlzlOw7IGbRAKVjJBPtg
#
#                     business_id  stars
# 1        7ATYjTIgM3jUlt4UM3IypQ      5
# 3        kxX2SOes4o-D3ZQBkiMRfA      5
# 5        04UD14gamNjLY0IDYVhHJg      1
# 13       RZtGWDLCAtuipwaZ-UfjmQ      4
# 16       YtSqYv1Q_pOltsVPSx54SA      5
# ...                         ...    ...
# ...

# %%
df_user_PHIL=df_user[df_user['user_id'].isin(df_review_PHIL['user_id'].unique())]

# %%
df_user_PHIL
# Out:
#                         user_id        name  \
# 0        qVc8ODYU5SZjKXVBgXdI7w      Walker
# 1        j14WgRoU_-2ZE1aw1dXrJg      Daniel
# 5        q_QQ5kBBwlCcbL1s4NVK3g        Jane
# 9        AUi8MPWJ0mLkMfwbui27lg        John
# 14       1McG5Rn_UDkmlkZOrsdptg      Teresa
# ...                         ...         ...
# 1987832  iZ0puydkFQlaSQAXbGtv1g  Dr. Sylvia
# 1987834  XTWARBzLbiJKQ1JeJB9f3g      Sakina
# 1987859  K-BNvWUCWEGUuBirCU4mmg        Jodi
# 1987862  cu_xPeMTm8qsWShBIHJeuw       Susan
# 1987892  fB3jbHi3m0L2KgGOxBv6uw     Jerrold
#
#                                                    friends  fans
# 0        NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267
# 1        ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...  3138
# 5        xBDpTUbai0DXrvxCe3X16Q, 7GPNBO496aecrjJfW6UWtg...  1357
# 9        gy5fWeSv3Gamuq9Ox4MV4g, lMr3LWU6kPFLTmCpDkACxg...     4
# 14       piejMEdRkGB7-1aL4lL5NQ, X0zFOU6iG95-feQKOXkgrA...     1
# ...

# %%
len(df_review_PHIL['business_id'].unique())
# Out:
# 14576

# %%
# Extract friends' user IDs from the filtered users
all_friends_user_ids = df_user_PHIL['friends'].str.split(', ').explode().unique()

# %%
df_user_and_friends_PHIL=df_user[df_user['user_id'].isin(all_friends_user_ids) | df_user['user_id'].isin(df_user_PHIL['user_id'])]

# %%
df_user_and_friends_PHIL
# Out:
#                         user_id        name  \
# 0        qVc8ODYU5SZjKXVBgXdI7w      Walker
# 1        j14WgRoU_-2ZE1aw1dXrJg      Daniel
# 2        2WnXYQFK0hXEoTxPtV2zvg       Steph
# 3        SZDeASXq7o05mMNLshsdIA        Gwen
# 5        q_QQ5kBBwlCcbL1s4NVK3g        Jane
# ...                         ...         ...
# 1987832  iZ0puydkFQlaSQAXbGtv1g  Dr. Sylvia
# 1987834  XTWARBzLbiJKQ1JeJB9f3g      Sakina
# 1987859  K-BNvWUCWEGUuBirCU4mmg        Jodi
# 1987862  cu_xPeMTm8qsWShBIHJeuw       Susan
# 1987892  fB3jbHi3m0L2KgGOxBv6uw     Jerrold
#
#                                                    friends  fans
# 0        NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267
# 1        ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...  3138
# 2        LuO3Bn4f3rlhyHIaNfTlnA, j9B4XdHUhDfTKVecyWQgyA...    52
# 3        enx1vVPnfdNUdPho6PH_wg, 4wOcvMLtU6a9Lslggq74Vg...    28
# 5        xBDpTUbai0DXrvxCe3X16Q, 7GPNBO496aecrjJfW6UWtg...  1357
# ...

# %%
import surprise

# %%
from surprise import Dataset, Reader, NormalPredictor, KNNBasic, KNNWithZScore, KNNWithMeans, KNNWithZScore, SVD
from surprise.model_selection import train_test_split, cross_validate
from collections import defaultdict
from surprise import accuracy

# %%
df_reviews_and_friends_PHIL=df_review[df_review['user_id'].isin(df_review_PHIL['user_id'])|df_review['user_id'].isin(all_friends_user_ids)]

# %%
df_reviews_and_friends_PHIL
# Out:
#                       review_id                 user_id  \
# 0        KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1        BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 2        saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3        AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 5        JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A
# ...                         ...                     ...
# 6990275  H0RIamZu0B0Ei0P4aeh3sQ  qskILQ3k0I_qcCMI-k6_QQ
# 6990276  shTPgbgdwTHSuU67mGCmZQ  Zo0th2m8Ez4gLSbHftiQvg
# 6990277  YNfNhgZlaaCO5Q_YJR4rEw  mm6E4FbCMwJmb7kPDZ5v2Q
# 6990278  i-I4ZOhoX70Nw5H0FwrQUA  YwAMC-jvZ1fvEUum6QkEkw
# 6990279  RwcKOdEuLRHNJe4M9-qpqg  6JehEvdoCvZPJ_XIxnzIIw
#
#                     business_id  stars
# 0        XQfwVwDr-v0ZS3_CbbE5Xw      3
# 1        7ATYjTIgM3jUlt4UM3IypQ      5
# 2        YjUWPpI6HXG530lwP-fb2A      3
# 3        kxX2SOes4o-D3ZQBkiMRfA      5
# 5        04UD14gamNjLY0IDYVhHJg      1
# ...                         ...    ...
# ...

# %%
cities=df_business['city'].unique()
for city in cities :
    print(city)
# Out:
# Santa Barbara
# Affton
# Tucson
# Philadelphia
# Green Lane
# Ashland City
# Brentwood
# St. Petersburg
# Nashville
# Land O' Lakes
# Tampa Bay
# Indianapolis
# Clearwater
# Largo
# New Orleans
# Kenner
# Edmonton
# Reno
# Newtown
# White House
# Boise
# Paoli
# Ardmore
# Exton
# Wilmington
# Edwardsville
# Sparks
# Alton
# Cherry Hill
# Bala Cynwyd
# Springfield
# Belleville
# Carmel
# Tampa
# Kennett Square
# Plymouth Meeting
# Harvey
# West Chester
# Meridian
# Hudson
# Fernley
# Williamstown
# Pinellas Park
# Glenolden
# Wesley Chapel
# Fishers
# Burlington
# Troy
# Camden
# Plainfield
# Bensalem
# Maplewood
# Saint Louis
# Fairview Heights
# Oro Valley
# Treasure Island
# Southampton
# Chalfont
# Willow Grove
# Voorhees
# Tarpon Springs
# Blue Bell
# Metairie
# Woodbury
# Brownsburg
# Norristown
# Land O Lakes
# Greenwood
# Saint Petersburg
# Brookhaven
# Haverford
# Glenside
# Moorestown
# Madison
# Ewing
# Levittown
# Gloucester Township
# Aston
# Riverview
# Warrington
# ...

# %%
dfb_franklin=df_business[df_business['city'].str.lower().isin(['franklin'])]

# %%
dfr_franklin=df_review[df_review['business_id'].isin(dfb_franklin['business_id'])]

# %%
dfu_franklin=df_user[df_user['user_id'].isin(dfr_franklin['user_id'].unique())]

# %%
dfu_franklin
# Out:
#                         user_id     name  \
# 26       kggqL33iZjeHmUn1Rtdjzg      Jay
# 37       KYBEVBAP7QUlt1LjmatTJg  Matthew
# 38       QJI9OSEn6ujRCtrX06vs1w        J
# 60       LwZJFLGxQwjjeOgpqTJnfw    Lucas
# 145      8zkkuk8KOoNojZhTx0j5KA  Melissa
# ...                         ...      ...
# 1987345  _zAH1G-sp3uNb9CGbY6mmQ      Jim
# 1987384  J5s1-bXtrYfhfDjLkEvnYw    Karry
# 1987558  b-FmQDc3uNtg7-WhS4wElQ    Celia
# 1987578  WXIaXyUFuP8Ci2CtehtBFA     Dana
# 1987624  2_q6zwXALVA3uBMIPJcR7Q    Susan
#
#                                                    friends  fans
# 26       5-cF_paDOoXPtgaAeE_XyQ, bwPqqPZ0u5ak_Lr45V1-CQ...     9
# 37       B7ecAeAIrXg7sgmabS38pg, tLrEDEs1Zu5NNmVuUivxvA...    63
# 38       RyPeT_ICAtX8ah9dhDpEFw, W8r4aKPZFT3GPIQQDbqB6Q...   316
# 60       RHsmgIvCfnFL7DPNptKY8A, mObXpXBnaOV_UhE0gWwvPQ...     5
# 145      p-lbHRoUAPC0OWmOXtzNIA, 0EXuIg5v5rnQzGh8P8uRKw...    11
# ...                                                    ...   ...
# ...

# %%
dfr_franklin
# Out:
#                       review_id                 user_id  \
# 406      89SF8MFoiY4mIhOgzAMVhA  S8rqFLdHCFAeibs52a4QpQ
# 425      HyD8P-CcFU3FR75T0dJAhA  YsaJXW7VWV2bhoN5tokKrg
# 693      3B41BdxNIENFP1EsCCybnw  B0fzg0eUWplNBzfSJsCFDg
# 802      h0N47vwJhQMBH9mscX9zhw  11jQWQYTJkzIE6o3s5ID4Q
# 804      cgppGTg8LpqZObn_k69w2Q  TSxzAqKzU2OvjWSLoSU8dA
# ...                         ...                     ...
# 6989373  Rjv4qf02STIbSUu5mq4W4w  U0kiORl1Gpc8K9jOWWgHzg
# 6989504  B50r7a0YV-WnBgf3bW-Dyw  H9AGj0t3ghPaHug0Ri3kOQ
# 6989863  lbhfWHGz3C6dyLp_aiKadg  EUITvLX8HgKpJPs8ngXRPw
# 6990131  sXMx4wAegK38PRbzyWe5Bg  4Ry0q14UDewv2LMa2wibCQ
# 6990230  4ncWtKqNnGcpHk2isnWZzg  jM9eD_bmcthFWliBUnWSLA
#
#                     business_id  stars
# 406      kKk_2OAnCRbxX5rLqQYBHg      5
# 425      HCqmx4ENAZ76SAjoalj-MQ      4
# 693      VUOD8yD1jwq_pqRP8EETBQ      3
# 802      hn3Rg2JrhQoDJBEhrpuwWg      1
# 804      skN2XhKXlcjf53uIwzAedw      5
# ...                         ...    ...
# ...

# %%
dfb_franklin
# Out:
#                    business_id                             name  \
# 245     uDQgmudYDKiB6n4vwbEeDg                        Chrysalis
# 309     96qKAK06EdkG6GPVxKDdTw           Goin' Postal Westhaven
# 316     1E9o1SNo7UTf1XHTFPv1_Q                Franklin Juice Co
# 512     PENtXTN19SYMMmFYYbA_Gw               Lubrication Corner
# 567     1s-vqaaGLscl7h4XIDO7LQ               Brilliant Nail Spa
# ...                        ...                              ...
# 149806  9BVO07g5PruWhckWtTdL4w            Enterprise Rent-A-Car
# 149901  SMrEjrZ9zH53DT5mN5Is9A  Lunatic Fringe Salon - Franklin
# 149929  tiYGClVGXW4tGrJVHHkOVQ            Whit's Frozen Custard
# 149943  rhTLD0ZUfdNjluBUFX79eQ               D1 Sports Training
# 150033  rhYObnJD91kq_b8qk5pU7g         Sky Zone Trampoline Park
#
#                                              address      city state  \
# 245                              9040 Carothers Pkwy  Franklin    TN
# ...

# %%
# Create a Surprise Dataset from the merged DataFrame
reader = Reader(rating_scale=(1, 5))  # Define the rating scale
data = Dataset.load_from_df(dfr_franklin[['user_id', 'business_id', 'stars']], reader)

# %%
# Split the data into training and testing sets
trainset, testset = train_test_split(data, test_size=0.2, random_state=42 )

# %%
# Define evaluation function
def evaluate_algorithm(algo, trainset, testset):
    algo.fit(trainset)
    predictions = algo.test(testset)

    # Compute and return RMSE
    rmse = accuracy.rmse(predictions)
    return rmse

# %%
ubcf_algo = KNNBasic(sim_options={'user_based': True})
ubcf_rmse = evaluate_algorithm(ubcf_algo, trainset, testset)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.5446

# %%
ibcf_algo = KNNBasic(sim_options={'user_based': False})
ibcf_rmse = evaluate_algorithm(ibcf_algo, trainset, testset)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.5667

# %%
svd_algo = SVD()
svd_rmse = evaluate_algorithm(svd_algo, trainset, testset)
# Out:
# RMSE: 1.3565

# %%
# Recommend top N items for a user using a recommender model
def recommend_top_n(algo, trainset, user_id, n=10):
    user_ratings = trainset.ur[user_id]
    items = [item_id for (item_id, _) in user_ratings]
    
    item_scores = {}
    for item_id in trainset.all_items():
        if item_id not in items:
            prediction = algo.predict(trainset.to_raw_uid(user_id), trainset.to_raw_iid(item_id), verbose=False)
            item_scores[item_id] = prediction.est
    
    top_items = sorted(item_scores, key=item_scores.get, reverse=True)[:n]

    #from raw_id to actual_id
    return [trainset.to_raw_iid(i) for i in top_items]

# %%
# Get recommendations for a specific user using the User-Based CF model
user_id = 6 # Change to the desired user ID
ubcf_top_items = recommend_top_n(svd_algo, trainset, user_id, n=5)
print("Top 5 User-Based CF Recommendations for User", trainset.to_raw_uid(user_id), ":", ubcf_top_items)
# Out:
# Top 5 User-Based CF Recommendations for User VU6jRnWoHVj7TSgw2jua5g : ['XysLDlS6X37LxMJ3VbUp-Q', '9-YPx17wKMIi7LyUSyRGog', 'bO4VP5rdmuaLQsik7OSgoA', 'EkYh3uDgTxLbaLEpRtg3Ig', 'FVLBH5AX5mBbH33STEOWbw']

# %%
df_business[df_business['business_id']=='FVLBH5AX5mBbH33STEOWbw']
# Out:
#                   business_id              name           address      city  \
# 67319  FVLBH5AX5mBbH33STEOWbw  Jalisco Taqueria  595 Hillsboro Rd  Franklin
#
#       state postal_code   latitude  longitude  stars  review_count  is_open  \
# 67319    TN       37064  35.932285 -86.878158    4.5            66        1
#
#                                               attributes  \
# 67319  {'RestaurantsGoodForGroups': 'True', 'WiFi': '...
#
#                  categories                                              hours
# 67319  Restaurants, Mexican  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...

# %%
df_aggregated = dfr_franklin.groupby(['user_id', 'business_id'])['stars'].mean().reset_index()
df_matrix = df_aggregated.pivot(index='user_id', columns='business_id', values='stars')

# %%
df_matrix
# Out:
# business_id             -4G38D90ZA4cmU95nRIjLQ  -5DcSecinHF2snC4eLv8WA  \
# user_id
# --611kCeaL-NClnOGIHxVA                     NaN                     NaN
# --RUqD8c6ibQSh9owooVxw                     NaN                     NaN
# --nJFgLzMnczShVC_CGslQ                     NaN                     NaN
# --vr-l7l3VDTr3D8hjXUtA                     NaN                     NaN
# -05wJ5BVkv8lYBIC_H5F-Q                     NaN                     NaN
# ...                                        ...                     ...
# zzEeZRchq3NsyIIZ1K4Aew                     NaN                     NaN
# zzSPpwEaLUNbRAWrj3y-yw                     NaN                     NaN
# zzUDLeUO6-UjNJVKK4tElg                     NaN                     NaN
# zzVqDGIqpBv_PJFCMZbpCw                     NaN                     NaN
# zzz-M4QvkEpUWWPL9RTzLA                     NaN                     NaN
#
# business_id             -85kJMtb9wqNWDT8yLbitw  -8ADRlWtPByYJac00xbe7w  \
# user_id
# ...

# %%
print(f"{df_matrix.notnull().sum().sum() / (df_matrix.shape[0] * df_matrix.shape[1]):.2%}")
# Out:
# 0.14%

# %%
df_matrix.notnull().sum(axis=0).hist()
# Out:
# <Axes: >

# %%
df_matrix.notnull().sum(axis=1).hist()
# Out:
# <Axes: >

# %%
df_matrix.mean(axis=1).hist()
# Out:
# <Axes: >

# %%
dfb_franklin['categories'].hist()
# Out:
# <Axes: >

# %%
df_matrix_categories=dfb_franklin.groupby('categories').count()

# %%
dfgrouped
# Out:
#                                                     business_id  name  \
# categories
# Accessories, Shoe Stores, Fashion, Women's Clot...            1     1
# Accessories, Shopping, Women's Clothing, Fashio...            1     1
# Accessories, Watch Repair, Jewelry, Shopping, F...            1     1
# Accessories, Women's Clothing, Home Decor, Fash...            1     1
# Active Life, Education, Sporting Goods, Guns & ...            1     1
# ...                                                         ...   ...
# Wineries, Italian, Arts & Entertainment, Restau...            1     1
# Women's Clothing, Fashion, Jewelry, Accessories...            1     1
# Women's Clothing, Shopping, Accessories, Fashio...            1     1
# Women's Clothing, Shopping, Jewelry, Home & Gar...            1     1
# Yoga, Active Life, Fitness & Instruction                      1     1
#
#                                                     address  city  state  \
# categories
# ...

# %%
df_matrix = dfr_franklin.pivot(index='user_id', columns='business_id', values='stars')
df_matrix
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[221], line 1
# ----> 1 df_matrix = dfr_franklin.pivot(index='user_id', columns='business_id', values='stars')
#       2 df_matrix
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\frame.py:8567, in DataFrame.pivot(self, index, columns, values)
#    8561 @Substitution("")
#    8562 @Appender(_shared_docs["pivot"])
# ...
